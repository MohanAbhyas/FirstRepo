# %% [markdown]
# <a href="https://colab.research.google.com/github/MohanAbhyas/FirstRepo/blob/master/Copy_of_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# sample_data  yolov3

# %%
# !./darknet detector train cfg/buoy.data cfg/buoy.cfg darknet53.conv.74
# Out:
# buoy
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   320 x 256 x   3   ->   320 x 256 x  32  0.142 BFLOPs
#     1 conv     64  3 x 3 / 2   320 x 256 x  32   ->   160 x 128 x  64  0.755 BFLOPs
#     2 conv     32  1 x 1 / 1   160 x 128 x  64   ->   160 x 128 x  32  0.084 BFLOPs
#     3 conv     64  3 x 3 / 1   160 x 128 x  32   ->   160 x 128 x  64  0.755 BFLOPs
#     4 res    1                 160 x 128 x  64   ->   160 x 128 x  64
#     5 conv    128  3 x 3 / 2   160 x 128 x  64   ->    80 x  64 x 128  0.755 BFLOPs
#     6 conv     64  1 x 1 / 1    80 x  64 x 128   ->    80 x  64 x  64  0.084 BFLOPs
#     7 conv    128  3 x 3 / 1    80 x  64 x  64   ->    80 x  64 x 128  0.755 BFLOPs
#     8 res    5                  80 x  64 x 128   ->    80 x  64 x 128
#     9 conv     64  1 x 1 / 1    80 x  64 x 128   ->    80 x  64 x  64  0.084 BFLOPs
#    10 conv    128  3 x 3 / 1    80 x  64 x  64   ->    80 x  64 x 128  0.755 BFLOPs
# ...
